# %% [markdown]
# # Flow Analysis
#
# In this notebook I want to create something that will read all of the files that we have created and make a dataframe that makes flow analysis simple.
#
# ### Folder  Structure
#
# All data needs to be in the data folder
#
# * Bipartite
# * Monopartite
# * Extinction
#
# Also excluded bipartite as we need all nodes to have the same meaning

# %%
import os 
import pandas as pd

# %%
os.listdir('data')
# Out:
# ['Extinction', 'Monopartite', 'Original_data', 'Bipartite']

# %% [markdown]
# ## Fetch all network files

# %%
def get_all_files(path):
    files = []
    for dirpath, _, filenames in os.walk(path):
        for f in filenames:
            files.append(os.path.abspath(os.path.join(dirpath, f)))
    return files

all_files = get_all_files('data') #Get all files
all_files= [f for f in all_files if f.find('Original_data')==-1] #Filter out input excel and matrix
all_files= [f for f in all_files if f.find('read')==-1] #filter readme
all_files= [f for f in all_files if f.find('.csv')==-1] #filter readme

#all_files= [f for f in all_files if f.find('Bipartite')==-1] #filter readme

all_files
# Out:
# ['/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_2',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_11',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_13',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_3',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_7',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_1',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_14',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_6',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_12',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_8',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_9',
#  '/home/ubuntu/Information_Theory/data/Bipartite_genus/freq_thr_4',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant72_num_freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1083_num_freq_thr_1',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant26_freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant1_freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1622_freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1256_num_freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1671_freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1679_num_freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant15_freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1147_freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant2_freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant0_num_freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant3_freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant2_num_freq_thr_1',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant64_num_freq_thr_1',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant15_num_freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1210_freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1436_num_freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1622_freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant4_freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1147_freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1322_freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_pol1460_freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant0_freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Extinction/rm_plant6_freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_2',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_11',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_13',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_3',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_7',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_1',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_14',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_6',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_12',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_8',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_9',
#  '/home/ubuntu/Information_Theory/data/Monopartite/freq_thr_4',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_5',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_10',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_2',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_11',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_13',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_15',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_3',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_7',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_1',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_14',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_6',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_0',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_12',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_8',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_9',
#  '/home/ubuntu/Information_Theory/data/Bipartite/freq_thr_4']

# %% [markdown]
# ## Functions to run infomap and store inputs in dataframe

# %%
import re 

def get_thres_f(path):
    thres_pos = path.find('freq_thr_')
    return path[thres_pos + len('freq_thr_'):]

def get_map_type(path):
    path=path.lower()
    out_type ='NA'
    #does the genus one last due to duplicity in name syntax
    map_type = ['bipartite', 'monopartite','extinction', 'bipartite_genus']
    for t in map_type:
        if path.find(t)!=-1: out_type = t
    return out_type

#just fetches the next number after the search match
def get_dropped(path, drop_key='rm_plant'):
    rm_out= 'NA'
    rm = path.find(drop_key)
    if rm != -1: 
        rm_out=int(re.search(r'\d+', path[rm+len(drop_key):]).group())
    return rm_out

def run_infomap(path):
    from infomap import Infomap
    im=Infomap(silent=True)
    im.readInputData(path)
    im.run()
    
    df_ = im.get_dataframe()
    df_['thres_freq']= get_thres_f(path)
    df_['type'] = get_map_type(path)
    df_['rm_plant'] = get_dropped(path)
    df_['rm_poll'] = get_dropped(path, drop_key='rm_pol')
    
    i=0
    for cl in im.codelengths:
        if i ==0:
            df_['codelengths']=cl
        else:
            df_['codelengths_'+str(i)]
            i+=1
    df_['num_nodes'] = im.num_nodes
    df_['num_leaf_modules']=im.num_leaf_modules
    df_['max_depth']=im.max_depth
    df_['num_top_modules']=im.num_top_modules
    df_['entropy_rate'] = im.entropy_rate
    df_['relative_codelength_savings'] =im.relative_codelength_savings
     
    return df_

# %% [markdown]
#  ### Test on one file
#  Extinction refers to mono extinction

# %%
run_infomap(all_files[0])
# Out:
#          path      flow                                     name  node_id  \
# 0   (1, 1, 1)  0.176471                                 Euonymus       34
# 1   (1, 1, 2)  0.024160                                Corydalis       27
# 2   (1, 1, 3)  0.010504                                    Rubus       70
# 3   (1, 1, 4)  0.000000   Xanthochroa luteipennis (Oed. : Col. )     1664
# 4   (1, 1, 5)  0.000000      Paratrichius doentzi (Sca. : Col. )     1497
# ..        ...       ...                                      ...      ...
# 69     (5, 2)  0.000000  Idiostrangalia contracta (Cer. : Col. )     1371
# 70     (6, 1)  0.006303                                    Aster       13
# 71     (6, 2)  0.000000       Agelastica coerulea (Chr. : Col. )     1005
# 72     (7, 1)  0.005252                                     Acer        0
# 73     (7, 2)  0.000000               EMPIDIDAE31 (Emp. : Dip. )     1278
#
#    thres_freq             type rm_plant rm_poll  codelengths  num_nodes  \
# 0           5  bipartite_genus       NA      NA     1.844816         74
# 1           5  bipartite_genus       NA      NA     1.844816         74
# 2           5  bipartite_genus       NA      NA     1.844816         74
# 3           5  bipartite_genus       NA      NA     1.844816         74
# 4           5  bipartite_genus       NA      NA     1.844816         74
# ..        ...              ...      ...     ...          ...        ...
# 69          5  bipartite_genus       NA      NA     1.844816         74
# 70          5  bipartite_genus       NA      NA     1.844816         74
# 71          5  bipartite_genus       NA      NA     1.844816         74
# 72          5  bipartite_genus       NA      NA     1.844816         74
# 73          5  bipartite_genus       NA      NA     1.844816         74
#
#     num_leaf_modules  max_depth  num_top_modules  entropy_rate  \
# 0                 13          3                7       2.03505
# 1                 13          3                7       2.03505
# 2                 13          3                7       2.03505
# 3                 13          3                7       2.03505
# 4                 13          3                7       2.03505
# ..               ...        ...              ...           ...
# 69                13          3                7       2.03505
# 70                13          3                7       2.03505
# 71                13          3                7       2.03505
# 72                13          3                7       2.03505
# 73                13          3                7       2.03505
#
#     relative_codelength_savings
# 0                      0.507431
# 1                      0.507431
# 2                      0.507431
# 3                      0.507431
# 4                      0.507431
# ..                          ...
# 69                     0.507431
# 70                     0.507431
# 71                     0.507431
# 72                     0.507431
# 73                     0.507431
#
# [74 rows x 15 columns]

# %% [markdown]
# ## Merge all the flow data for into one dataframe

# %%
i=0
for f in all_files:
    if i==0:
        df=run_infomap(f)
    else:
        df=pd.concat( [df,run_infomap(f)], ignore_index=True)
    i+=1
df
# Out:
#             path      flow                                    name  node_id  \
# 0      (1, 1, 1)  0.176471                                Euonymus       34
# 1      (1, 1, 2)  0.024160                               Corydalis       27
# 2      (1, 1, 3)  0.010504                                   Rubus       70
# 3      (1, 1, 4)  0.000000  Xanthochroa luteipennis (Oed. : Col. )     1664
# 4      (1, 1, 5)  0.000000     Paratrichius doentzi (Sca. : Col. )     1497
# ...          ...       ...                                     ...      ...
# 14989    (12, 3)  0.000000       Cerceris carinalis (Sph. : Hym. )     1159
# 14990    (13, 1)  0.004892                               rufinerve        0
# 14991    (13, 2)  0.000000              EMPIDIDAE31 (Emp. : Dip. )     1278
# 14992    (14, 1)  0.003914                                  annuus       77
# 14993    (14, 2)  0.000000   Blitopertha orientalis (Sca. : Col. )     1100
#
#       thres_freq             type rm_plant rm_poll  codelengths  num_nodes  \
# 0              5  bipartite_genus       NA      NA     1.844816         74
# 1              5  bipartite_genus       NA      NA     1.844816         74
# 2              5  bipartite_genus       NA      NA     1.844816         74
# 3              5  bipartite_genus       NA      NA     1.844816         74
# 4              5  bipartite_genus       NA      NA     1.844816         74
# ...          ...              ...      ...     ...          ...        ...
# 14989          4        bipartite       NA      NA     2.500228         98
# 14990          4        bipartite       NA      NA     2.500228         98
# 14991          4        bipartite       NA      NA     2.500228         98
# 14992          4        bipartite       NA      NA     2.500228         98
# 14993          4        bipartite       NA      NA     2.500228         98
#
#        num_leaf_modules  max_depth  num_top_modules  entropy_rate  \
# 0                    13          3                7      2.035050
# 1                    13          3                7      2.035050
# 2                    13          3                7      2.035050
# 3                    13          3                7      2.035050
# 4                    13          3                7      2.035050
# ...                 ...        ...              ...           ...
# 14989                14          2               14      1.926738
# 14990                14          2               14      1.926738
# 14991                14          2               14      1.926738
# 14992                14          2               14      1.926738
# 14993                14          2               14      1.926738
#
#        relative_codelength_savings
# 0                         0.507431
# 1                         0.507431
# 2                         0.507431
# 3                         0.507431
# 4                         0.507431
# ...                            ...
# 14989                     0.416526
# 14990                     0.416526
# 14991                     0.416526
# 14992                     0.416526
# 14993                     0.416526
#
# [14994 rows x 15 columns]

# %%
df.to_csv('infomap_results_all_data.csv')

# %% [markdown]
# Not sure if this makes sense does look cool though

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Plot the distribution of clarity ratings, conditional on carat
sns.displot(
    data=df,
    x="flow", hue="type",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %% [markdown]
# ### Identifying which models have max flow

# %%
df.sort_values('flow',  ascending=False)[1:10]
# Out:
#          path      flow       name  node_id thres_freq             type  \
# 12909  (1, 1)  0.427056     aemula       11         15        bipartite
# 12878  (1, 1)  0.389234     aemula       11         13        bipartite
# 14761  (1, 1)  0.385356     aemula       11         12        bipartite
# 12840  (1, 1)  0.362319     aemula       11         11        bipartite
# 12572  (1, 1)  0.349650     aemula       11         10        bipartite
# 374    (1, 1)  0.333333  Antenoron       10         13  bipartite_genus
# 2217   (1, 1)  0.333333  Antenoron       10         12  bipartite_genus
# 336    (1, 1)  0.321543  Antenoron       10         11  bipartite_genus
# 1373   (1, 1)  0.317604  Antenoron       10         14  bipartite_genus
#
#       rm_plant rm_poll  codelengths  num_nodes  num_leaf_modules  max_depth  \
# 12909       NA      NA     0.351709         18                 6          2
# 12878       NA      NA     0.274522         31                11          2
# 14761       NA      NA     0.325427         34                11          2
# 12840       NA      NA     0.305972         38                12          2
# 12572       NA      NA     0.452508         39                11          2
# 374         NA      NA     0.320587         32                10          2
# 2217        NA      NA     0.321656         35                10          2
# 336         NA      NA     0.310279         38                11          2
# 1373        NA      NA     0.328151         31                10          2
#
#        num_top_modules  entropy_rate  relative_codelength_savings
# 12909                6      0.778805                     0.859444
# 12878               11      0.948625                     0.909392
# 14761               11      1.060566                     0.895541
# 12840               12      1.100830                     0.905761
# 12572               11      1.127079                     0.863793
# 374                 10      1.057259                     0.897677
# 2217                10      1.233227                     0.897176
# 336                 11      1.229382                     0.904052
# 1373                10      0.958437                     0.896443

# %%
df.groupby(['type'])['flow'].mean().to_frame()
# Out:
#                  flow
# type
# bipartite    0.006390
# extinction   0.003292
# monopartite  0.006520

# %% [markdown]
# ### Node comparison

# %%
df[df['node_id']==4]
# Out:
#             path      flow        name  node_id thres_freq         type  \
# 253      (4, 24)  0.000209           4        4          0   extinction
# 1013     (4, 24)  0.000209           4        4          1   extinction
# 1545      (4, 1)  0.043011           4        4          5   extinction
# 1611      (5, 2)  0.023929           4        4         15   extinction
# 1648     (10, 1)  0.009964           4        4         10   extinction
# 1902     (4, 24)  0.000209           4        4          0   extinction
# 2419      (4, 2)  0.026316           4        4         15   extinction
# 2728     (5, 24)  0.000209           4        4          0   extinction
# 3210      (4, 1)  0.043011           4        4          5   extinction
# 3298     (11, 1)  0.009632           4        4         10   extinction
# 3336     (11, 1)  0.009402           4        4         10   extinction
# 3591     (4, 24)  0.000209           4        4          0   extinction
# 4111      (5, 2)  0.023929           4        4         15   extinction
# 4474      (8, 1)  0.020894           4        4          1   extinction
# 5128     (4, 24)  0.000209           4        4          1   extinction
# 5888     (4, 24)  0.000209           4        4          0   extinction
# 6429     (10, 1)  0.009615           4        4         10   extinction
# 6785     (6, 24)  0.000212           4        4          0   extinction
# 7241   (2, 2, 1)  0.040000           4        4          5   extinction
# 7304     (11, 1)  0.009402           4        4         10   extinction
# 7326   (1, 3, 1)  0.043668           4        4          5   extinction
# 7396      (5, 2)  0.032646           4        4         15   extinction
# 7425      (4, 1)  0.043431           4        4          5   extinction
# 7514     (11, 1)  0.009402           4        4         10   extinction
# 7542      (4, 1)  0.043011           4        4          5   extinction
# 7621      (4, 1)  0.043011           4        4          5  monopartite
# 7710     (11, 1)  0.009402           4        4         10  monopartite
# 7857     (10, 1)  0.014608           4        4          2  monopartite
# 7971     (11, 1)  0.009735           4        4         11  monopartite
# 7997      (9, 1)  0.013105           4        4         13  monopartite
# 8016      (5, 2)  0.023929           4        4         15  monopartite
# 8039      (2, 1)  0.037625           4        4          3  monopartite
# 8179   (2, 1, 1)  0.145182           4        4          7  monopartite
# 1611                 6                     0.544045
# 1648                10                     0.595895
# 1902                35                     0.261381
# 2419                 6                     0.606544
# 2728                34                     0.259912
# 3210                17                     0.447742
# 3298                11                     0.588363
# 3336                11                     0.593297
# 3591                35                     0.261033
# 4111                 6                     0.544045
# 4474                35                     0.261250
# 5128                35                     0.261033
# 5888                35                     0.261033
# 6429                10                     0.582374
# 6785                34                     0.263123
# 7241                 8                     0.492933
# 7304                11                     0.593297
# 7326                 7                     0.443717
# 7396                 6                     0.557202
# 7425                17                     0.447599
# 7514                11                     0.593297
# 7542                17                     0.447742
# 7621                17                     0.447742
# 7710                11                     0.593297
# 7857                22                     0.332536
# 7971                11                     0.606690
# 7997                11                     0.600402
# 8016                 6                     0.544045
# 8039                21                     0.392220
# 8179                 8                     0.517336
# 8574                35                     0.261250
# 8989                 7                     0.563169
# 9037                 7                     0.465908
# 9317                35                     0.261033
# 9847                11                     0.593264
# 9875                 9                     0.529596
# 9930                 9                     0.536048
# 9968                 5                     0.414870
# 11145               18                     0.133276
# 12008               18                     0.133276

# %%
df.groupby(['node_id', 'type'])['flow'].mean().unstack()
# Out:
# type     bipartite  extinction  monopartite
# node_id
# 0         0.003808    0.040656     0.069445
# 1         0.000836    0.030713     0.039436
# 2         0.000836    0.067136     0.055578
# 3         0.000836    0.034567     0.040391
# 4         0.000418    0.017718     0.038640
# ...            ...         ...          ...
# 1674      0.000000    0.000535     0.001439
# 1675      0.000000    0.000209     0.000209
# 1676      0.000000    0.000209     0.000209
# 1677      0.000000    0.000209     0.000209
# 1678      0.000000    0.000244     0.000313
#
# [773 rows x 3 columns]

# %% [markdown]
# The mean of the node id is not useful so we drop it

# %%
df.groupby(['type','thres_freq']).mean()
# Out:
#                                 flow      node_id  codelengths   num_nodes  \
# type            thres_freq
# bipartite       0           0.001299  1186.187013     4.334238  770.000000
#                 1           0.001299  1186.187013     4.334238  770.000000
#                 10          0.025641   750.871795     0.452508   39.000000
#                 11          0.026316   769.578947     0.305972   38.000000
#                 12          0.029412   767.558824     0.325427   34.000000
#                 13          0.032258   763.161290     0.274522   31.000000
#                 14          0.047619   745.000000     0.327393   21.000000
#                 15          0.055556   701.944444     0.351709   18.000000
#                 2           0.004367  1009.305677     3.451194  229.000000
#                 3           0.007042   884.345070     2.750464  142.000000
#                 4           0.010204   807.969388     2.500228   98.000000
#                 5           0.012195   788.134146     1.997352   82.000000
#                 6           0.013889   778.263889     1.761454   72.000000
#                 7           0.016949   777.389831     1.245003   59.000000
#                 8           0.018519   798.833333     1.044831   54.000000
#                 9           0.021277   775.829787     0.996144   47.000000
# bipartite_genus 0           0.001335  1217.169559     3.985846  749.000000
#                 1           0.001335  1217.169559     3.985846  749.000000
#                 10          0.025641   810.692308     0.648632   39.000000
#                 11          0.026316   804.789474     0.310279   38.000000
#                 12          0.028571   813.114286     0.321656   35.000000
#                 13          0.031250   769.125000     0.320587   32.000000
#                 9                  12.000000   2.000000        12.000000
# extinction      0                  35.666886   3.000000        34.666886
#                 1                  36.000000   3.000000        35.000000
#                 10                 11.680180   3.000000        10.680180
#                 15                  6.000000   2.000000         6.000000
#                 5                  17.165605   2.496815        13.853503
# monopartite     0                  36.000000   3.000000        35.000000
#                 1                  36.000000   3.000000        35.000000
#                 10                 12.000000   3.000000        11.000000
#                 11                 12.000000   3.000000        11.000000
#                 12                 11.000000   2.000000        11.000000
#                 13                 11.000000   2.000000        11.000000
#                 14                  7.000000   2.000000         7.000000
#                 15                  6.000000   2.000000         6.000000
#                 2                  24.000000   3.000000        22.000000
#                 3                  22.000000   3.000000        21.000000
#                 4                  19.000000   3.000000         5.000000
#                 5                  17.000000   2.000000        17.000000
#                 6                  16.000000   3.000000         7.000000
#                 7                  14.000000   3.000000         8.000000
#                 8                  13.000000   3.000000         9.000000
#                 9                  13.000000   3.000000         9.000000
#
#                             entropy_rate  relative_codelength_savings
# type            thres_freq
# bipartite       0               4.363059                     0.133276
#                 1               4.363059                     0.133276
#                 10              1.127079                     0.863793
#                 11              1.100830                     0.905761
#                 12              1.060566                     0.895541
#                 13              0.948625                     0.909392
#                 14              0.898742                     0.873462
#                 15              0.778805                     0.859444
#                 2               2.912778                     0.262616
#                 3               2.266284                     0.386622
#                 4               1.926738                     0.416526
#                 5               1.726035                     0.517965
#                 6               1.622783                     0.563393
#                 7               1.475205                     0.672172
#                 8               1.439763                     0.714840
#                 9               1.265930                     0.723571
# bipartite_genus 0               4.734758                     0.116310
#                 1               4.734758                     0.116310
#                 10              1.376571                     0.798775
#                 11              1.229382                     0.904052
#                 12              1.233227                     0.897176
#                 13              1.057259                     0.897677
#                 14              0.958437                     0.896443
#                 15              0.875177                     0.888983
#                 2               3.301597                     0.240547
#                 3               2.654579                     0.371821
#                 4               2.308530                     0.405380
#                 5               2.035050                     0.507431
#                 6               1.890843                     0.567232
#                 7               1.712688                     0.690706
#                 8               1.591049                     0.762891
#                 9               1.399706                     0.768283
# extinction      0               2.990097                     0.261252
#                 1               2.992879                     0.261070
#                 10              0.763257                     0.591113
#                 15              0.524000                     0.562386
#                 5               1.309799                     0.454536
# monopartite     0               2.993227                     0.261033
#                 1               2.992596                     0.261250
#                 10              0.766390                     0.593297
#                 11              0.714801                     0.606690
#                 12              0.705358                     0.593264
#                 13              0.637256                     0.600402
#                 14              0.590060                     0.563169
#                 15              0.570815                     0.544045
#                 2               2.151191                     0.332536
#                 3               1.716750                     0.392220
#                 4               1.500846                     0.414870
#                 5               1.325192                     0.447742
#                 6               1.237795                     0.465908
#                 7               1.073851                     0.517336
#                 8               1.016224                     0.529596
#                 9               0.907441                     0.536048

# %%
df.groupby(['type','thres_freq']).mean().sort_values('relative_codelength_savings',  ascending=False)
# Out:
#                                 flow      node_id  codelengths   num_nodes  \
# type            thres_freq
# bipartite       13          0.032258   763.161290     0.274522   31.000000
#                 15              0.778805                     0.859444
# bipartite_genus 10              1.376571                     0.798775
#                 9               1.399706                     0.768283
#                 8               1.591049                     0.762891
# bipartite       9               1.265930                     0.723571
#                 8               1.439763                     0.714840
# bipartite_genus 7               1.712688                     0.690706
# bipartite       7               1.475205                     0.672172
# monopartite     11              0.714801                     0.606690
#                 13              0.637256                     0.600402
#                 10              0.766390                     0.593297
#                 12              0.705358                     0.593264
# extinction      10              0.763257                     0.591113
# bipartite_genus 6               1.890843                     0.567232
# bipartite       6               1.622783                     0.563393
# monopartite     14              0.590060                     0.563169
# extinction      15              0.524000                     0.562386
# monopartite     15              0.570815                     0.544045
#                 9               0.907441                     0.536048
#                 8               1.016224                     0.529596
# bipartite       5               1.726035                     0.517965
# monopartite     7               1.073851                     0.517336
# bipartite_genus 5               2.035050                     0.507431
# monopartite     6               1.237795                     0.465908
# extinction      5               1.309799                     0.454536
# monopartite     5               1.325192                     0.447742
# bipartite       4               1.926738                     0.416526
# monopartite     4               1.500846                     0.414870
# bipartite_genus 4               2.308530                     0.405380
# monopartite     3               1.716750                     0.392220
# bipartite       3               2.266284                     0.386622
# bipartite_genus 3               2.654579                     0.371821
# monopartite     2               2.151191                     0.332536
# bipartite       2               2.912778                     0.262616
# extinction      0               2.990097                     0.261252
# monopartite     1               2.992596                     0.261250
# extinction      1               2.992879                     0.261070
# monopartite     0               2.993227                     0.261033
# bipartite_genus 2               3.301597                     0.240547
# bipartite       1               4.363059                     0.133276
#                 0               4.363059                     0.133276
# bipartite_genus 1               4.734758                     0.116310
#                 0               4.734758                     0.116310

# %% [markdown]
# ## Syntax Transfroms: Only run if needed
#
# To build a comparible dataframe all of the files need to be in the same syntax we set the pollenators to start at 1000 so they are distinct from the plant nodes

# %%
import re
def update_pol_drop_path(path, start_pol): # changes the rm_pol information in file path 
    rm_out= 'NA'
    drop_key='rm_pol'
    rm = path.find(drop_key)
    if rm != -1: 
        old_num=int(re.search(r'\d+', path[rm+len(drop_key):]).group())
        if old_num<1000: #old format(added the number of pollenators)
            old_start_pol= 93
        else: #1000 added for visual ease
            old_start_pol= 1000
        rm_out=str(old_num-old_start_pol+start_pol)
        new_path = path[:rm]+drop_key+rm_out +path[rm+len(drop_key)+len(str(old_num)):]
        os.rename(path,new_path)

def reformat_poll(path, start_pol = 1000):
    with open(path, 'r') as file:
        out_list =[]
        for line in file:
            out_line = line
            columns=line.split(' ')
            if columns[0].isnumeric():
                if int(columns[0])>93:# leave the plant numbers unchanged start after them
                    if int(columns[0])<1000: #old format(added the number of pollenators)
                        old_start_pol= 93
                    else: #1000 added for visual ease
                        old_start_pol= 1001 # due to slight mist
                    columns[0]=str(int(columns[0])-old_start_pol+start_pol)
                    out_line= ' '.join(columns)
            out_list.append(out_line)
    with open(path, 'w') as file:
        for line in out_list: 
            file.write(line)
    update_pol_drop_path(path, start_pol)

# %%
for file in all_files:
    reformat_poll(file)
