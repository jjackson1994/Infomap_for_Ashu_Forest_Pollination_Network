# %% [markdown]
# # Flow Analysis
#
# In this notebook I want to create something that will read all of the files that we have created and make a dataframe that makes flow analysis simple.
#
# ### Folder  Structure
#
# All data needs to be in the data folder
#
# * Bipartite
# * Monopartite
# * Extinction
#
# Also excluded bipartite as we need all nodes to have the same meaning

# %%
import os 
import pandas as pd

# %% [markdown]
# ## Fetch all network files

# %%
def get_all_files(path):
    files = []
    for dirpath, _, filenames in os.walk(path):
        for f in filenames:
            files.append(os.path.abspath(os.path.join(dirpath, f)))
    return files

all_files = get_all_files('data') #Get all complete file paths with folder, then remove unwanted
all_files= [f for f in all_files if f.find('Original_data')==-1 and f.find('read')==-1 and
            f.find('.csv')==-1 and f.find('Species_V_Genus')]

print('We are using', len(all_files), ' networks')
data_folders = [f for f in os.listdir('data') if os.path.isdir(os.path.join('data',f)) and  f!= 'Original_data']
L_data_folders = [len(f) for f in data_folders]
for i in range(len(data_folders)): # minus 1 for readme files
    print('In ', data_folders[i],' there are ', len(os.listdir(os.path.join('data',data_folders[i]))) - 1, 'networks')
# Out:
# We are using 73  networks
# In  Bipartite_genus  there are  16 networks
# In  Extinction  there are  25 networks
# In  Monopartite  there are  16 networks
# In  Bipartite  there are  16 networks

# %% [markdown]
# ## Functions to run infomap
#
# In this section our objective is to collectivise the runs so we store run inputs and key infomap outputs. In the follwing section will will build a large dataframe to enable effective data analysis.
#
# We obtain the input conditions from the file name paths using our naming syntax when setting.
# * The various run types that we conducted we split into folders
# * threshold frequncy and dropped values are are added to the file name

# %%
import re 

def get_thres_f(path):
    thres_pos = path.find('freq_thr_')
    return int(path[thres_pos + len('freq_thr_'):])

def get_map_type(path):
    path=path.lower()
    out_type ='NA'
    #does the genus one last due to duplicity in name syntax
    map_type = ['bipartite', 'monopartite','extinction', 'bipartite_genus']
    for t in map_type:
        if path.find(t)!=-1: out_type = t
    return out_type

#just fetches the next number after the search match
def get_dropped(path, drop_key='rm_plant'):
    rm_out= 'NA'
    rm = path.find(drop_key)
    if rm != -1: 
        rm_out=int(re.search(r'\d+', path[rm+len(drop_key):]).group())
    return rm_out

def run_infomap(path):
    from infomap import Infomap
    im=Infomap(silent=True)
    im.readInputData(path)
    im.run()
    
    df_ = im.get_dataframe()
    # Store inputs
    df_['thres_freq']= get_thres_f(path)
    df_['type'] = get_map_type(path)
    df_['rm_plant'] = get_dropped(path)
    df_['rm_poll'] = get_dropped(path, drop_key='rm_pol')
    
    #Store outputs
    i=0
    for cl in im.codelengths:
        if i ==0:
            df_['codelengths']=cl
        else:
            df_['codelengths_'+str(i)]
            i+=1
    df_['num_nodes'] = im.num_nodes
    df_['num_leaf_modules']=im.num_leaf_modules
    df_['max_depth']=im.max_depth
    df_['num_top_modules']=im.num_top_modules
    df_['entropy_rate'] = im.entropy_rate
    df_['relative_codelength_savings'] =im.relative_codelength_savings
    return df_

# %% [markdown]
#  ### Running Infomap

# %%
run_infomap(all_files[0])
# Out:
#          path      flow                                     name  node_id  \
# 0   (1, 1, 1)  0.176471                                 Euonymus       34
# 1   (1, 1, 2)  0.024160                                Corydalis       27
# 2   (1, 1, 3)  0.010504                                    Rubus       70
# 3   (1, 1, 4)  0.000000   Xanthochroa luteipennis (Oed. : Col. )     1664
# 4   (1, 1, 5)  0.000000      Paratrichius doentzi (Sca. : Col. )     1497
# ..        ...       ...                                      ...      ...
# 69     (5, 2)  0.000000  Idiostrangalia contracta (Cer. : Col. )     1371
# 70     (6, 1)  0.006303                                    Aster       13
# 71     (6, 2)  0.000000       Agelastica coerulea (Chr. : Col. )     1005
# 72     (7, 1)  0.005252                                     Acer        0
# 73     (7, 2)  0.000000               EMPIDIDAE31 (Emp. : Dip. )     1278
#
#     thres_freq             type rm_plant rm_poll  codelengths  num_nodes  \
# ...

# %% [markdown]
# ## Merge all the flow data for into one dataframe

# %%
i=0
for f in all_files:
    if i==0:
        df=run_infomap(f)
    else:
        df=pd.concat([df,run_infomap(f)], ignore_index=True)
    i+=1
df
# Out:
#             path      flow                                    name  node_id  \
# 0      (1, 1, 1)  0.176471                                Euonymus       34
# 1      (1, 1, 2)  0.024160                               Corydalis       27
# 2      (1, 1, 3)  0.010504                                   Rubus       70
# 3      (1, 1, 4)  0.000000  Xanthochroa luteipennis (Oed. : Col. )     1664
# 4      (1, 1, 5)  0.000000     Paratrichius doentzi (Sca. : Col. )     1497
# ...          ...       ...                                     ...      ...
# 15039    (12, 3)  0.000000       Cerceris carinalis (Sph. : Hym. )     1159
# 15040    (13, 1)  0.004892                               rufinerve        0
# 15041    (13, 2)  0.000000              EMPIDIDAE31 (Emp. : Dip. )     1278
# 15042    (14, 1)  0.003914                                  annuus       77
# 15043    (14, 2)  0.000000   Blitopertha orientalis (Sca. : Col. )     1100
#
# ...

# %%
df.to_csv('infomap_results_all_data.csv')

# %% [markdown]
# ## Demonstration
# Aggrigated by mean

# %%
df.groupby(['type','thres_freq']).mean().sort_values(['type','thres_freq'],ascending=False).drop(columns='node_id')
# Out:
#                                 flow  codelengths   num_nodes  \
# type            thres_freq
# monopartite     15          0.055556     1.619532   18.000000
#                 14          0.047619     1.663591   21.000000
#                 13          0.032258     1.653937   31.000000
#                 12          0.029412     1.743339   34.000000
#                 11          0.026316     1.750734   38.000000
#                 10          0.025641     1.837204   39.000000
#                 9           0.021277     2.190089   47.000000
#                 8           0.018519     2.312862   54.000000
#                 7           0.016949     2.433729   59.000000
#                 6           0.013889     2.801379   72.000000
#                 5           0.012195     2.972793   82.000000
#                 4           0.010204     3.261452   98.000000
#                 3           0.007042     3.613138  142.000000
#                 2           0.004367     4.227035  229.000000
# ...

# %%
df.groupby(['type','thres_freq']).median().sort_values(['type','thres_freq'],ascending=False).drop(columns='node_id')
# Out:
#                                 flow  codelengths  num_nodes  \
# type            thres_freq
# monopartite     15          0.045093     1.619532       18.0
#                 14          0.035802     1.663591       21.0
#                 13          0.020704     1.653937       31.0
#                 12          0.019268     1.743339       34.0
#                 11          0.017663     1.750734       38.0
#                 10          0.017483     1.837204       39.0
#                 9           0.015106     2.190089       47.0
#                 8           0.009749     2.312862       54.0
#                 7           0.009211     2.433729       59.0
#                 6           0.008121     2.801379       72.0
#                 5           0.006508     2.972793       82.0
#                 4           0.004892     3.261452       98.0
#                 3           0.002515     3.613138      142.0
#                 2           0.001331     4.227035      229.0
# ...

# %%
df.groupby(['type'])['flow'].mean().to_frame()
# Out:
#                  flow
# type
# bipartite    0.006390
# extinction   0.003292
# monopartite  0.006520

# %% [markdown]
# ## Visualisation

# %%
node_dict=pd.Series(df.name.values,index=df.node_id).to_dict()
node_dict[]

# %% [markdown]
# ### Plants

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.set_facecolor('papayawhip')
plt.xticks(np.arange(0,100, step=5))
plot_=sns.scatterplot(data=df[df['node_id']<100], x="node_id", y='flow', hue='type',
                size='thres_freq',palette = "ch:rot=-.25,hue=1,light=.75")

# %% [markdown]
# ### Pollenators

# %%
fig, ax = plt.subplots(figsize=(15,10))
ax.set_facecolor('papayawhip')
plt.xticks(np.arange(1000,1700, step=20), rotation = 90)
sns.scatterplot(data=df[df['node_id']>100], x="node_id", y='flow', hue='type',
                size='thres_freq',palette = "ch:rot=-.25,hue=1,light=.75")
# Out:
# <AxesSubplot:xlabel='node_id', ylabel='flow'>

# %% [markdown]
# ### Flow

# %%
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_theme(style="whitegrid")

# Plot the distribution of clarity ratings, conditional on carat
sns.displot(data=df,
    x="flow", hue="type",
    kind="kde", aspect=3,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %% [markdown]
# ### Code savings

# %%
import seaborn as sns

sns.set_theme(style="whitegrid")
# Plot the distribution of clarity ratings, conditional on carat
sns.displot(data=df,
    x="relative_codelength_savings", hue="type",
    kind="kde", aspect=3,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %% [markdown]
# ## Monopartite Analysis

# %% [markdown]
# The plots below use the kernel desnity esitimate to visualise the where the dominant sources of flow were for the

# %%
mono_df = df[df['type']=='monopartite']
mono_df
# Out:
#          path      flow                                   name  node_id  \
# 10036  (1, 1)  0.126898                                 aemula       11
# 10037  (1, 2)  0.060195          ANTHOMYIIDAE38 (Ant. : Dip. )     1054
# 10038  (1, 3)  0.019523        DELTOCEPHALIDAE4 (Del. : Hem. )     1233
# 10039  (1, 4)  0.013015     Melanostoma scalare (Syr. : Dip. )     1431
# 10040  (1, 5)  0.010846     Podabrus temporalis (Can. : Col. )     1520
# ...       ...       ...                                    ...      ...
# 12535  (5, 3)  0.002935    Ectinohoplia obducta (Sca. : Col. )     1252
# 12536  (6, 1)  0.002446                              rufinerve        0
# 12537  (6, 2)  0.002446             EMPIDIDAE31 (Emp. : Dip. )     1278
# 12538  (7, 1)  0.001957                                 annuus       77
# 12539  (7, 2)  0.001957  Blitopertha orientalis (Sca. : Col. )     1100
#
#        thres_freq         type rm_plant rm_poll  codelengths  num_nodes  \
# ...

# %% [markdown]
# ## Plants

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.xticks(np.arange(0,100, step=5))
ax.set_facecolor('papayawhip')
sns.scatterplot(data=mono_df[mono_df['node_id']<100], x="node_id", y='flow', hue='thres_freq',
                size='num_nodes',palette = "ch:rot=-.25,hue=1,light=.75")
# Out:
# <AxesSubplot:xlabel='node_id', ylabel='flow'>

# %% [markdown]
# ## Pollenators

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.xticks(np.arange(1000,1700, step=20), rotation = 90)
ax.set_facecolor('papayawhip')
sns.scatterplot(data=mono_df[mono_df['node_id']>100], x="node_id", y='flow', hue='thres_freq',
                size='num_nodes',palette = "ch:rot=-.25,hue=1,light=.75")
# Out:
# <AxesSubplot:xlabel='node_id', ylabel='flow'>

# %% [markdown]
# ## Syntax Transforms: Only run if needed
#
# To build a comparible dataframe all of the files need to be in the same syntax we set the pollenators to start at 1000 so they are distinct from the plant nodes

# %%
import re
def update_pol_drop_path(path, start_pol): # changes the rm_pol information in file path 
    rm_out= 'NA'
    drop_key='rm_pol'
    rm = path.find(drop_key)
    if rm != -1: 
        old_num=int(re.search(r'\d+', path[rm+len(drop_key):]).group())
        if old_num<1000: #old format(added the number of pollenators)
            old_start_pol= 93
        else: #1000 added for visual ease
            old_start_pol= 1000
        rm_out=str(old_num-old_start_pol+start_pol)
        new_path = path[:rm]+drop_key+rm_out +path[rm+len(drop_key)+len(str(old_num)):]
        os.rename(path,new_path)

def reformat_poll(path, start_pol = 1000):
    with open(path, 'r') as file:
        out_list =[]
        for line in file:
            out_line = line
            columns=line.split(' ')
            if columns[0].isnumeric():
                if int(columns[0])>93:# leave the plant numbers unchanged start after them
                    if int(columns[0])<1000: #old format(added the number of pollenators)
                        old_start_pol= 93
                    else: #1000 added for visual ease
                        old_start_pol= 1001 # due to slight mist
                    columns[0]=str(int(columns[0])-old_start_pol+start_pol)
                    out_line= ' '.join(columns)
            out_list.append(out_line)
    with open(path, 'w') as file:
        for line in out_list: 
            file.write(line)
    update_pol_drop_path(path, start_pol)

# %%
for file in all_files:
    reformat_poll(file)
